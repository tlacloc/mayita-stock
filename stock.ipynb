# %% [markdown]
# <center><h2 style="font-size:2em;color:#840700">   Web scraping de una página web para generar un database  de stock con el fin de facilitar organización de ventas  </h4></center>

# %% [markdown]
# ## Primeros pasos

# %% [markdown]
# Se desea a partir de un archivo de texto donde se encuentren los productos de venta de una página en específico, hacer un análisis de cierta información que estos tengan.

# %% [markdown]
# ## Archivos y librerías

# %%
#librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#web scraping
import requests
from urllib.request import urlopen
import bs4
from fake_useragent import UserAgent

# %%
#path
figuras = 'figuras/'
datos = 'datos/'

#titulos de archivos especificos
crude_data = datos + 'urls.txt'
productos_csv = datos + 'productos.csv'

# %% [markdown]
# ## Primero se recopilará información de cada pagina en crude_data

# %%
# Using readlines()
urls_file = open(crude_data, 'r')
urls = urls_file.readlines()
urls
# Out:
# ['https://www.nihaojewelry.com/retro-small-round-buckle-fine-belt-female-gun-black-buckle-hollow-eye-ladies-belt-fashion-puffy-belt-women-nhpo198250.html']

# %% [markdown]
# ## Generación de stock

# %%
stock = pd.read_csv(productos_csv)
stock
# Out:
# Empty DataFrame
# Columns: [nombre,  codigo,  peso (g),  material,  precio compra,  precio venta,  existencia,  url,  picture path]
# Index: []

# %% [markdown]
# ## web scraping

# %%
#fake user to access https
user_agent = UserAgent()

# %%
## getting the reponse from the page using get method of requests module
page = requests.get(urls[0], headers={"user-agent": user_agent.chrome})

## storing the content of the page in a variable
html = page.content
## creating BeautifulSoup object
page_soup = bs4.BeautifulSoup(html, "html.parser")

# %%
page_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="97asd3684l8t1ttdtlliio84g5yw6m" name="facebook-domain-verification">
# <meta content="fda229edef75759a28b28c060cd36803" name="p:domain_verify">
# <link href="https://www.nihaojewelry.com/image/icon/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://www.nihaojewelry.com/image/icon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans" rel="stylesheet"/>
# <!-- Google Tag Manager -->
# <script>
#         (function (w, d, s, l, i) {
#             w[l] = w[l] || [];
#             w[l].push({
#                 'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#             });
#             var f = d.getElementsByTagName(s)[0],
#                     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#             j.async = true;
#             j.src =
#                     'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-KZ9LVD7');
#     </script>
# <!-- End Google Tag Manager -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-40712316-1"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#
#         function gtag() {
#             dataLayer.push(arguments);
#         }
#
#         gtag('js', new Date());
#         gtag('config', 'UA-40712316-1');
#     </script>
# <!-- bing -->
# <script>(function(w,d,t,r,u){var f,n,i;w[u]=w[u]||[],f=function(){var o={ti:"56001045"};o.q=w[u],w[u]=new UET(o),w[u].push("pageLoad")},n=d.createElement(t),n.src=r,n.async=1,n.onload=n.onreadystatechange=function(){var s=this.readyState;s&&s!=="loaded"&&s!=="complete"||(f(),n.onload=n.onreadystatechange=null)},i=d.getElementsByTagName(t)[0],i.parentNode.insertBefore(n,i)})(window,document,"script","//bat.bing.com/bat.js","uetq");</script>
# <script src="https://www.nihaojewelry.com/pages/nhjewelryEvent.js?v=20210310"></script>
# <script>
#         (function() {
#
#             window['nhEventCustomerId'] = '';
#             window['nhEventCustomerId'] = window['nhEventCustomerId'] != '' ? window['nhEventCustomerId'] : null;
#             // page duration
#             if (!window['nhDurationDisabled']) {
#                 __nhEvent.visitDuration({customerId: window['nhEventCustomerId'], event: 11}, null);
#                 setInterval(() => {
#                     if (!window['nhDurationDisabled']) {
#                         __nhEvent.visitDuration({customerId: window['nhEventCustomerId'], event: 11}, null);
#                     }
#                 }, 60000);
#             }
#         })();
#     </script>
# <title>404 Not Found</title>
# <link href="https://www.nihaojewelry.com/es/retro-small-round-buckle-fine-belt-female-gun-black-buckle-hollow-eye-ladies-belt-fashion-puffy-belt-women-nhpo198250.html" rel="canonical">
# <link href="https://m.nihaojewelry.com/es/retro-small-round-buckle-fine-belt-female-gun-black-buckle-hollow-eye-ladies-belt-fashion-puffy-belt-women-nhpo198250.html" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="https://www.nihaojewelry.com/retro-small-round-buckle-fine-belt-female-gun-black-buckle-hollow-eye-ladies-belt-fashion-puffy-belt-women-nhpo198250.html" hreflang="en" rel="alternate"/>
# <link href="https://www.nihaojewelry.com/fr/retro-small-round-buckle-fine-belt-female-gun-black-buckle-hollow-eye-ladies-belt-fashion-puffy-belt-women-nhpo198250.html" hreflang="fr" rel="alternate"/>
# <link href="https://www.nihaojewelry.com/de/retro-small-round-buckle-fine-belt-female-gun-black-buckle-hollow-eye-ladies-belt-fashion-puffy-belt-women-nhpo198250.html" hreflang="de" rel="alternate"/>
# <link href="https://www.nihaojewelry.com/es/retro-small-round-buckle-fine-belt-female-gun-black-buckle-hollow-eye-ladies-belt-fashion-puffy-belt-women-nhpo198250.html" hreflang="es" rel="alternate"/>
# <link href="https://www.nihaojewelry.com/cssPage/layout.css?v=20210310" rel="stylesheet"/>
# <script type="application/ld+json">{
#             "@context": "http://schema.org",
#             "@type": "WebSite",
#             "url": "https://www.nihaojewelry.com/es/",
#             "name": "nihaojewelry.com",
#             "headline": "Joyas por Mayoreo, Bisuteria al por Mayor, Bisuteria Mayoreo - Nihaojewelry Españole",
#             "about": "Más de 10000 joyas y accesorios al por mayor en línea para boutiques están disponibles a precios económicos en Nihaojewelry. Encuentra bisuteria mayoreo aquí, sin pedido mínimo y entrega rápida a México, España y otros países.",
#             "potentialAction": {
#                 "@type": "SearchAction",
#                 "target": "https://www.nihaojewelry.com/es/productSearch/result?query={search_term_string}",
#                 "query-input": "required name=search_term_string"
#             }
#         }
#     </script>
# </link></meta></meta></head>
# <body>
# <a class="g-top-ad_bd" href="https://www.nihaojewelry.com/es/customer/account/create" rel="nofollow">
# <div class="g-top-ad g-wrap j_top_ad">
# <img alt="tips" src="https://img.nihaojewelry.com/media/2021/3/11/1369950687261233152.jpg" style="height: 100%; width: 100%;display: block;"/>
# <i class="i_close_top_ad close-icon"></i>
# </div>
# </a>
# <div class="g-top g-wrap">
# <div class="g-wrap_bds" style="width: 1378px">
# <div class="g-top_left">
# <span class="title"><a href="https://www.nihaojewelry.com/es/">Bisuteria al Por Mayor!</a> </span>
# <a class="hint" href="https://www.nihaojewelry.com/es/customer/account/login" rel="nofollow"> Iniciar sesión</a>
#                 <span>or</span>
#                 <a href="https://www.nihaojewelry.com/es/customer/account/create" rel="nofollow">Unirse gratis</a>
# <div class="reward-tag"><span style="padding-top: 20px;padding-left: 20px;color: #a03ea3;">$</span><span style="padding-left: 37px;font-size: 12px;font-weight: 600">US $ 5</span></div>
# </div>
# <div class="g-top_left">
# <a class="fb" href="https://www.facebook.com/v3.1/dialog/oauth?client_id=297633578266781&amp;redirect_uri=https://www.nihaojewelry.com/connect/facebook/success&amp;scope=public_profile,email&amp;state=NHLOGIN" style="border-radius: 3px;
#     width: 100px;
#     height: 25px;
#     line-height: 25px;
#     text-align: center;
#     background-color: #495f96;
#     margin-top: 9px;">
# <i class="fb-icon"></i>
#                 Facebook
#             </a>
# </div>
# <ul class="g-top_right">
# <li>
# <span style="margin-right: 8px;">Idioma:</span>
# <div class="menu-root lang">
# <i class="icon-country active es" data-country="227"></i>
# <span>Español</span>
# <i class="arrow"></i>
# <div class="menu-root_child">
# <a class="icon-country en" href="https://www.nihaojewelry.com/retro-small-round-buckle-fine-belt-female-gun-black-buckle-hollow-eye-ladies-belt-fashion-puffy-belt-women-nhpo198250.html">English</a>
# <a class="icon-country fr" href="https://www.nihaojewelry.com/fr/retro-small-round-buckle-fine-belt-female-gun-black-buckle-hollow-eye-ladies-belt-fashion-puffy-belt-women-nhpo198250.html">French</a>
# <a class="icon-country de" href="https://www.nihaojewelry.com/de/retro-small-round-buckle-fine-belt-female-gun-black-buckle-hollow-eye-ladies-belt-fashion-puffy-belt-women-nhpo198250.html">Deutsch</a>
# <a class="icon-country es" href="https://www.nihaojewelry.com/es/retro-small-round-buckle-fine-belt-female-gun-black-buckle-hollow-eye-ladies-belt-fashion-puffy-belt-women-nhpo198250.html">Español</a>
# </div>
# </div>
# </li>
# <li>
# <div class="menu-root">
# <i class="i currency"></i>
# <span>Moneda: MXN</span>
# <i class="arrow"></i>
# <div class="menu-root_child">
# <a class="icon-country eur" onclick="currency('EUR')" rel="nofollow">EUR</a>
# <a class="icon-country usd" onclick="currency('USD')" rel="nofollow">USD</a>
# <a class="icon-country aud" onclick="currency('AUD')" rel="nofollow">AUD</a>
# <a class="icon-country gbp" onclick="currency('GBP')" rel="nofollow">GBP</a>
# <a class="icon-country cad" onclick="currency('CAD')" rel="nofollow">CAD</a>
# <a class="icon-country mxn" onclick="currency('MXN')" rel="nofollow">MXN</a>
# <a class="icon-country ngn" onclick="currency('NGN')" rel="nofollow">NGN</a>
# </div>
# </div>
# </li>
# <li>
# <div class="menu-root my-account">
# <i class="i account"></i>
# <span>Mi cuenta</span>
# <i class="arrow"></i>
# <div class="menu-root_child">
# <a class="" href="https://www.nihaojewelry.com/es/customer/account" rel="nofollow">&gt; Panel de cuenta</a>
# <a href="https://www.nihaojewelry.com/es/customer/customerWishList" rel="nofollow">&gt; Lista de deseos</a>
# <a class="" href="https://www.nihaojewelry.com/es/customer/customerOrdersList" rel="nofollow">&gt; Mis pedidos</a>
# <a class="" href="https://www.nihaojewelry.com/es/customer/customerReviewsList" rel="nofollow">&gt; Mis opiniones</a>
# <a class="" href="https://www.nihaojewelry.com/es/customer/customerMessage" rel="nofollow">&gt; Mis etiquetas</a>
# </div>
# </div>
# </li>
# <li>
# <div class="menu-root">
# <a href="https://www.nihaojewelry.com/es/customer/orderTrack" style="color:inherit;">
# <i class="iconfont icon-nh-airplane" style="font-size: 18px"></i>
# <span style="margin-left: 4px">Rastreo de orden</span>
# </a>
# </div>
# </li>
# <li>
# <div class="menu-root">
# <i class="i phone"></i>
# <span>Contáctenos</span>
# <i class="arrow"></i>
# <div class="menu-root_child concat">
# <div class="row">
# <div class="title-head">
# <i class="msg"></i>
# <span style="color: #333333">Chat en vivo</span>
# </div>
# </div>
# <div class="row">
# <div class="title-head">
# <i class="email"></i>
# <span style="color: #333333">Contáctenos</span>
# </div>
# <a class="row-link" href="https://www.nihaojewelry.com/es/contacts" rel="nofollow">Dejando un mensaje</a>
# <span class="row-link">info@nihaojewelry.co.uk</span>
# </div>
# <div class="row">
# <div class="title-head">
# <i class="phone"></i>
# <span style="color: #333333">whatsapp</span>
# </div>
# <a class="row-link" href="https://api.whatsapp.com/send?phone=8615958105548" rel="nofollow" target="_blank">+86 159 5810 5548 (Español)</a>
# <a class="row-link" href="https://api.whatsapp.com/send?phone=8618957961698" rel="nofollow" target="_blank">+86 189 5796 1698 (English)</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <div class="menu-root">
# <i class="i faq"></i>
# <span><a href="https://www.nihaojewelry.com/es/faqs" rel="nofollow" style="font-size: 12px;color: white" target="_blank">faqs</a></span>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="g-head g-wrap" id="g-head">
# <div class="g-wrap_bd">
# <p class="logo" title="Nihaojewelry">
# <a href="https://www.nihaojewelry.com/es/" title="Nihaojewelry">Nihaojewelry</a>
# </p>
# <div class="search" id="search">
# <form action="https://www.nihaojewelry.com/es/productSearch/result" autocomplete="off" class="search_bd" id="searchPrdForm" onsubmit="return searchPrd()">
# <div class="form-input-content">
# <div class="select-area-wrap">
# <div class="select-area j_select" style="display: flex;justify-content: center;align-items: center;height: 37px;">
# <span class="category-name" style="margin-right: 0;white-space: nowrap;flex: 1 1 auto;overflow: hidden;text-overflow: ellipsis;">
#                                 All Categories
#                             </span>
# <input id="categoryId" name="category" type="hidden" value="0"/>
# <i class="arrow" style="flex: 1 0 auto;margin: 0 2px;"></i>
# </div>
# <ul class="j_select_list select-area-result" style="width: auto;">
# <li><input class="category-id" type="hidden" value="0"/><span class="title">All Categories</span></li>
# <li><input class="category-id" type="hidden" value="1243"/><span class="title">Joyería de Fantasía</span></li>
# <li><input class="category-id" type="hidden" value="2253"/><span class="title">joyería para niños</span></li>
# <li><input class="category-id" type="hidden" value="2254"/><span class="title">Bisutería para hombres</span></li>
# <li><input class="category-id" type="hidden" value="835"/><span class="title">Choker</span></li>
# <li><input class="category-id" type="hidden" value="1244"/><span class="title">Collares</span></li>
# <li><input class="category-id" type="hidden" value="2243"/><span class="title">Collar de capas</span></li>
# <li><input class="category-id" type="hidden" value="1245"/><span class="title">Aretes</span></li>
# <li><input class="category-id" type="hidden" value="1926"/><span class="title">Aretes de broche</span></li>
# <li><input class="category-id" type="hidden" value="1934"/><span class="title">Aretes Colgantes</span></li>
# <li><input class="category-id" type="hidden" value="1966"/><span class="title">Aretes De Tachuela</span></li>
# <li><input class="category-id" type="hidden" value="1970"/><span class="title">Aretes De Aro</span></li>
# <li><input class="category-id" type="hidden" value="1246"/><span class="title">Anillos</span></li>
# <li><input class="category-id" type="hidden" value="1247"/><span class="title">Pulseras &amp; Brazaletes</span></li>
# <li><input class="category-id" type="hidden" value="1248"/><span class="title">Juego de Joyería</span></li>
# <li><input class="category-id" type="hidden" value="1249"/><span class="title">Broches</span></li>
# <li><input class="category-id" type="hidden" value="1250"/><span class="title">Cadenas Para El Cuerpo</span></li>
# <li><input class="category-id" type="hidden" value="1535"/><span class="title">Bisuteria Para Novias</span></li>
# <li><input class="category-id" type="hidden" value="1251"/><span class="title">Accesorios para el cabello </span></li>
# <li><input class="category-id" type="hidden" value="2256"/><span class="title">accesorios pelo niña</span></li>
# <li><input class="category-id" type="hidden" value="1885"/><span class="title">Diadema</span></li>
# <li><input class="category-id" type="hidden" value="2203"/><span class="title">pinzas para el cabello</span></li>
# <li><input class="category-id" type="hidden" value="2204"/><span class="title">gomas para el pelo</span></li>
# <li><input class="category-id" type="hidden" value="1252"/><span class="title">Bisutería Fina</span></li>
# <li><input class="category-id" type="hidden" value="1253"/><span class="title">Joyería cristal</span></li>
# <li><input class="category-id" type="hidden" value="1311"/><span class="title">Collar Cristal</span></li>
# <li><input class="category-id" type="hidden" value="1312"/><span class="title">Arete Cristal</span></li>
# <li><input class="category-id" type="hidden" value="1313"/><span class="title">Broche Cristal</span></li>
# <li><input class="category-id" type="hidden" value="1314"/><span class="title">Brazalete Cristal</span></li>
# <li><input class="category-id" type="hidden" value="1315"/><span class="title">Anillo Cristal</span></li>
# <li><input class="category-id" type="hidden" value="1316"/><span class="title">Juego de Joyería Cristal</span></li>
# <li><input class="category-id" type="hidden" value="1317"/><span class="title">Accesorio de Pelo Cristal</span></li>
# <li><input class="category-id" type="hidden" value="1254"/><span class="title">Joyería de acero de Inoxidable</span></li>
# <li><input class="category-id" type="hidden" value="1319"/><span class="title">Collar Acero &amp;Titanio</span></li>
# <li><input class="category-id" type="hidden" value="1320"/><span class="title">Brazalete Acero &amp;Titanio</span></li>
# <li><input class="category-id" type="hidden" value="1321"/><span class="title">Arete Acero &amp;Titanio</span></li>
# <li><input class="category-id" type="hidden" value="1322"/><span class="title">Anillo Acero &amp;Titanio</span></li>
# <li><input class="category-id" type="hidden" value="1255"/><span class="title">Joyería Plata 925</span></li>
# <li><input class="category-id" type="hidden" value="1257"/><span class="title">joyas con piedras naturales</span></li>
# <li><input class="category-id" type="hidden" value="1545"/><span class="title">Joyería Personalizada</span></li>
# <li><input class="category-id" type="hidden" value="1599"/><span class="title">Joyas de cobre y circonio</span></li>
# <li><input class="category-id" type="hidden" value="1258"/><span class="title">Bolsos de Moda</span></li>
# <li><input class="category-id" type="hidden" value="1259"/><span class="title">Bolsos para Dama</span></li>
# <li><input class="category-id" type="hidden" value="1260"/><span class="title">Mochilas</span></li>
# <li><input class="category-id" type="hidden" value="1262"/><span class="title">Bolsos Fiesta</span></li>
# <li><input class="category-id" type="hidden" value="1263"/><span class="title">Carteras</span></li>
# <li><input class="category-id" type="hidden" value="1306"/><span class="title">Bolsas de Mano</span></li>
# <li><input class="category-id" type="hidden" value="1264"/><span class="title">Ropa de moda</span></li>
# <li><input class="category-id" type="hidden" value="2250"/><span class="title">Pijama</span></li>
# <li><input class="category-id" type="hidden" value="1265"/><span class="title">Vestidos mujer </span></li>
# <li><input class="category-id" type="hidden" value="1266"/><span class="title">Conjunto de Ropa</span></li>
# <li><input class="category-id" type="hidden" value="1267"/><span class="title">Lenceria </span></li>
# <li><input class="category-id" type="hidden" value="1268"/><span class="title">Abrigo &amp; Chaqueta</span></li>
# <li><input class="category-id" type="hidden" value="1269"/><span class="title">Camiseta</span></li>
# <li><input class="category-id" type="hidden" value="1270"/><span class="title">Pantalones</span></li>
# <li><input class="category-id" type="hidden" value="1271"/><span class="title">Leggings</span></li>
# <li><input class="category-id" type="hidden" value="1272"/><span class="title">calcetines</span></li>
# <li><input class="category-id" type="hidden" value="1273"/><span class="title">Tallas Grandes</span></li>
# <li><input class="category-id" type="hidden" value="1373"/><span class="title">Blusas</span></li>
# <li><input class="category-id" type="hidden" value="1598"/><span class="title">Parches para Ropa</span></li>
# <li><input class="category-id" type="hidden" value="1664"/><span class="title">Suéter</span></li>
# <li><input class="category-id" type="hidden" value="1534"/><span class="title">Zapatos de Mujer</span></li>
# <li><input class="category-id" type="hidden" value="2237"/><span class="title">Zaptos de tacón</span></li>
# <li><input class="category-id" type="hidden" value="2240"/><span class="title">zapatos planos</span></li>
# <li><input class="category-id" type="hidden" value="2241"/><span class="title">Zapatillas de casa</span></li>
# <li><input class="category-id" type="hidden" value="1274"/><span class="title">Relojes de Moda</span></li>
# <li><input class="category-id" type="hidden" value="1275"/><span class="title">Relojes mujer</span></li>
# <li><input class="category-id" type="hidden" value="1276"/><span class="title">Relojes hombre</span></li>
# <li><input class="category-id" type="hidden" value="1277"/><span class="title">Relojes Niños</span></li>
# <li><input class="category-id" type="hidden" value="1278"/><span class="title">Bufandas</span></li>
# <li><input class="category-id" type="hidden" value="1279"/><span class="title">Bufanda Gasa</span></li>
# <li><input class="category-id" type="hidden" value="1280"/><span class="title">Bufanda Poliéster</span></li>
# <li><input class="category-id" type="hidden" value="1281"/><span class="title">Bufanda Cachemir</span></li>
# <li><input class="category-id" type="hidden" value="1282"/><span class="title">Pañuelo playa</span></li>
# <li><input class="category-id" type="hidden" value="1283"/><span class="title">Trajes de baño</span></li>
# <li><input class="category-id" type="hidden" value="1284"/><span class="title">Bikini</span></li>
# <li><input class="category-id" type="hidden" value="1285"/><span class="title">Monokinis</span></li>
# <li><input class="category-id" type="hidden" value="1286"/><span class="title">Tallas grandes</span></li>
# <li><input class="category-id" type="hidden" value="1338"/><span class="title">Accesorios de Natación</span></li>
# <li><input class="category-id" type="hidden" value="1287"/><span class="title">Accesorios de Moda</span></li>
# <li><input class="category-id" type="hidden" value="2252"/><span class="title">Suministros para la fiesta</span></li>
# <li><input class="category-id" type="hidden" value="1288"/><span class="title">Gorros de Moda</span></li>
# <li><input class="category-id" type="hidden" value="1289"/><span class="title">Lentes de Sol</span></li>
# <li><input class="category-id" type="hidden" value="1290"/><span class="title">Protectores para celulares</span></li>
# <li><input class="category-id" type="hidden" value="1291"/><span class="title">Llaveros</span></li>
# <li><input class="category-id" type="hidden" value="1292"/><span class="title">Accesorios de Joyería</span></li>
# <li><input class="category-id" type="hidden" value="1428"/><span class="title">herramientas y brochas de maquillaje</span></li>
# <li><input class="category-id" type="hidden" value="1641"/><span class="title">Cabello &amp; Pelucas</span></li>
# <li><input class="category-id" type="hidden" value="1902"/><span class="title">Cadena de Lentes</span></li>
# <li><input class="category-id" type="hidden" value="1916"/><span class="title">Cinturón de Mujer</span></li>
# <li><input class="category-id" type="hidden" value="1985"/><span class="title">Joyeros</span></li>
# <li><input class="category-id" type="hidden" value="2087"/><span class="title">Madre &amp; Bebé</span></li>
# <li><input class="category-id" type="hidden" value="2096"/><span class="title">Lenceria Premama</span></li>
# <li><input class="category-id" type="hidden" value="2095"/><span class="title">Ropa de bebé</span></li>
# <li><input class="category-id" type="hidden" value="2205"/><span class="title">Productos creativos</span></li>
# <li><input class="category-id" type="hidden" value="1860"/><span class="title">Papeleria kawaii</span></li>
# </ul>
# </div>
# <div id="header-search-input-tags-container"></div>
# <div class="input-wrap" id="input-wrap">
# <input class="j_search_input search-input" id="querya" name="query" placeholder="What Are You Looking For ?" style="position: relative; padding:9px 0;" type="text" value=""/>
# <div id="showQuerya" style="display: none; margin-top: 40px;background-color: white; z-index: 1;width: 427px;
#                             position: absolute;left: 111px;top: -1px;">
# <ul id="addShow">
# <li class="keyslist">
# <a href="https://www.nihaojewelry.com/es/lindo-papeleria">
# <span class="keystyle">
#                         papeleria
#                     </span>
# </a>
# </li>
# <li class="keyslist">
# <a href="https://www.nihaojewelry.com/es/fashion-bags">
# <span class="keystyle">
#                         bolsas
#                     </span>
# </a>
# </li>
# <li class="keyslist">
# <a href="https://www.nihaojewelry.com/es/wholesale/anillo-de-serpiente">
# <span class="keystyle">
#                        	Anillo De Serpiente
#                     </span>
# </a>
# </li>
# <li class="keyslist">
# <a href="https://www.nihaojewelry.com/es/wholesale/joyas-de-mal-de-ojo">
# <span class="keystyle">
#                        Joyas De Mal De Ojo
#                     </span>
# </a>
# </li>
# <li class="keyslist">
# <a href="https://www.nihaojewelry.com/es/wholesale/collares-de-letras">
# <span class="keystyle">
# 								  Letras
# 							 </span>
# </a>
# </li>
# <li class="keyslist">
# <a href="https://www.nihaojewelry.com/es/key-chains">
# <span class="keystyle">Llavero</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <label class="camera-pic" style="position: absolute;top: 0;right: 60px;width: 38px;text-align: center;cursor: pointer;">
# <span class="iconfont icon-nh-camera" style="display: block;width: 100%;height: 32px;font-size: 30px;line-height: 32px;text-align: center;margin-top: 3px;pointer-events: none;"></span>
# <input accept="image/jpeg,image/png" id="test-pic" name="" style="width: 0;height: 0;left: 0;top: 0;" type="file">
# </input></label>
# <div class="camera-pic-hint">
# <div class="camera-pic-hint-content">
# Subir imagen buscar productos similares!                        </div>
# </div>
# <button class="search-btn" onclick="searchPrd()"></button>
# </div>
# </form>
# </div>
# <div class="menu-root"></div>
# <div class="right" id="rightCart">
# <a class="row tag-icon" href="https://blog.nihaojewelry.com/es/como-comprar-bisuteria-con-precio-mayoreo-en-nihaojewelry/" target="_blank">
# <i class="car"></i>
# <div class="total-wrap" style="float: right">
# <span class="title">Start</span><br/>
# <span class="title">Wholesale</span>
# </div>
# </a>
# <div class="row line" id="rowLine"></div>
# <div class="row cart-btn" id="J_HeadCart">
# <div class="cart-back">
# <a class="total-info tag-icon" href="https://www.nihaojewelry.com/es/checkout/cart" rel="nofollow">
# <i class="cart"></i>
# <div class="total-wrap">
# <p class="tag j_total_quantity">0</p>
# <p class="title">Carro</p>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="g-nav g-wrap">
# <div class="g-wrap_bd g-nav_bd">
# <div class="menu-head float-child" id="navigationShowIndex">
# <p class="head-title">Default Category</p>
# <div class="menu-head_child">
# <div class="menu-row">
# <a class="row-link" href="https://www.nihaojewelry.com/es/the-latest-updates">
# <i class="i-menu-1"></i>
# <span>Última actualización</span>
# </a>
# <div class="sub-child" style="width: 730px">
# <div class="row" style="width: 730px">
# <div style="float: left;padding-top: 10px">
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/03-13-2021" rel="nofollow">Mar.13,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/03-12-2021" rel="nofollow">Mar.12,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/03-11-2021" rel="nofollow">Mar.11,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/03-10-2021" rel="nofollow">Mar.10,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/03-09-2021" rel="nofollow">Mar.09,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/03-08-2021" rel="nofollow">Mar.08,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/03-06-2021" rel="nofollow">Mar.06,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/03-05-2021" rel="nofollow">Mar.05,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/03-04-2021" rel="nofollow">Mar.04,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/03-03-2021" rel="nofollow">Mar.03,2021</a>
# </div>
# </div>
# <div style="float: left;padding-top: 10px">
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/03-01-2021" rel="nofollow">Mar.01,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-27-2021" rel="nofollow">Feb.27,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-26-2021" rel="nofollow">Feb.26,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-25-2021" rel="nofollow">Feb.25,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-24-2021" rel="nofollow">Feb.24,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-23-2021" rel="nofollow">Feb.23,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-22-2021" rel="nofollow">Feb.22,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-20-2021" rel="nofollow">Feb.20,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-19-2021" rel="nofollow">Feb.19,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-18-2021" rel="nofollow">Feb.18,2021</a>
# </div>
# </div>
# <div style="float: left;padding-top: 10px">
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-16-2021" rel="nofollow">Feb.16,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-14-2021" rel="nofollow">Feb.14,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-06-2021" rel="nofollow">Feb.06,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-05-2021" rel="nofollow">Feb.05,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-04-2021" rel="nofollow">Feb.04,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-03-2021" rel="nofollow">Feb.03,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-02-2021" rel="nofollow">Feb.02,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates/02-01-2021" rel="nofollow">Feb.01,2021</a>
# </div>
# <div class="row-item-last-update">
# <a class="title-last-update" href="https://www.nihaojewelry.com/es/the-latest-updates?elm=100" rel="nofollow">More ...</a>
# </div>
# </div>
# </div>
# <div style="margin-top: 300px;">
# <div style="width: 140px;float: left;">
# <a class="a-img" href="https://www.nihaojewelry.com/es/wholesale-jewelry-mexican">
# <img alt="mexico jewelry" src="https://www.nihaojewelry.com/es/images/category/mexico-jewelry.png"/>
# <div class="row-update-title">
#                                                     Mexicano jewelry &gt;
#                                                 </div>
# </a>
# </div>
# <div style="    width: 140px;
#     margin-left: 20px;
#     position: relative;
#     top: 24px;
#     float: left;">
# <a class="a-img" href="https://www.nihaojewelry.com/es/wholesale-jewelry-usa">
# <div class="row-usa-jewelry-img">
# <img alt="USA jewelry" src="https://www.nihaojewelry.com/es/images/category/usa-jewelry.png"/>
# </div>
# <div class="row-update-title">
#                                                     USA jewelry &gt;
#                                                 </div>
# </a>
# </div>
# <div style="     width: 140px;
#     margin-left: 320px;
#     position: relative;
#     top: 16px;">
# <a class="a-img" href="https://www.nihaojewelry.com/es/wholesale-jewelry-europe">
# <div class="row-europen-jewelry-img">
# <img alt="Europe Jewelry" src="https://www.nihaojewelry.com/es/images/category/europen-jewelry.png"/>
# </div>
# <div class="row-update-title">
#                                                     Europeo jewelry &gt;
#                                                 </div>
# </a>
# </div>
# </div>
# <div style="    float: right;
#     width: 220px;
#     position: relative;
#     top: -320px;
#     left: -10px;">
# <a href="https://www.nihaojewelry.com/es/the-latest-updates">
# <img alt="latest updates products" src="https://www.nihaojewelry.com/es/images/category/vintage-earring-flowers.png"/>
# </a>
# </div>
# </div>
# </div>
# <div class="menu-row">
# <a class="row-link" href="https://www.nihaojewelry.com/es/fashion-jewelry" style="height: 38px;">
# <i class="i-menu-2"></i>
# <span>Joyería de Fantasía</span>
# </a>
# <div class="sub-child" style="width: 400px;height: 470px;">
# <div class="row" style="width: 400px;height: 470px;float: left;background-color: #fff;">
# <div class="row-item-fashion-jewelry">
# <a class="title-1" href="https://www.nihaojewelry.com/es/collares" style="height: 38px;">Collares</a>
# </div>
# <div class="row-item-fashion-jewelry">
# <a class="title-1" href="https://www.nihaojewelry.com/es/earrings" style="height: 38px;">Aretes</a>
# </div>
# <div class="row-item-fashion-jewelry">
# <a class="title-1" href="https://www.nihaojewelry.com/es/rings" style="height: 38px;">Anillos</a>
# </div>
# <div class="row-item-fashion-jewelry">
# <a class="title-1" href="https://www.nihaojewelry.com/es/bracelets-bangles" style="height: 38px;">Pulseras &amp; Brazaletes</a>
# </div>
# <div class="row-item-fashion-jewelry">
# <a class="title-1" href="https://www.nihaojewelry.com/es/jewelry-sets" style="height: 38px;">Juego de Joyería</a>
# </div>
# <div class="row-item-fashion-jewelry">
# <a class="title-1" href="https://www.nihaojewelry.com/es/brooches" style="height: 38px;">Broches</a>
# </div>
# <div class="row-item-fashion-jewelry">
# <a class="title-1" href="https://www.nihaojewelry.com/es/body-jewelry" style="height: 38px;">Cadena del Cuerpo</a>
# </div>
# <div class="row-item-fashion-jewelry">
# <a class="title-1" href="https://www.nihaojewelry.com/es/chocker" style="height: 38px;">Choker</a>
# </div>
# <div class="row-item-fashion-jewelry">
# <a class="title-1" href="https://www.nihaojewelry.com/es/joyer-a-para-ni-os" style="height: 38px;">Joyería para Niños</a>
# </div>
# <div class="row-item-fashion-jewelry">
# <a class="title-1" href="https://www.nihaojewelry.com/es/joyeria-de-boda" style="height: 38px;">Joyería de Boda</a>
# </div>
# <div class="row-item-fashion-jewelry">
# <a class="title-1" href="https://www.nihaojewelry.com/es/Bisuter-a-para-hombres" style="height: 38px;">Bisutería para hombres</a>
# </div>
# <div>
# <a class="a-img" href="https://www.nihaojewelry.com/es/fashion-jewelry">
# <div class="row-fashion-jewelry-img" style="top: 15px;position: absolute;">
# <img alt="Joyería de Fantasía" src="https://img.nihaojewelry.com/media/2020/8/26/1298460112368832512_thumb_200x450/Joyería-de-Fantasía.jpg" style="height: 455px"/>
# </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="menu-row">
# <a class="row-link" href="https://www.nihaojewelry.com/es/hair-accessories" style="height: 38px;">
# <i class="i-menu-16"></i>
# <span>Accesorios para pelo</span>
# </a>
# <div class="sub-child" style="width: 400px;height: 470px;">
# <div class="row" style="width: 400px;height: 470px;float: left;background-color: #fff;">
# <a href="https://www.nihaojewelry.com/es/diadema" style="margin-left: 25px;height: auto;margin-top: 15px;margin-bottom: 15px;display: inline-block;width: 165px;">
# <img alt="Banda de pelo y diademas" src="https://img.nihaojewelry.com/media/2021/1/18/1351139718422728704.jpg" style="width: 165px;height: 165px;display: block;"/>
# <p style="font-size: 15px;font-weight: 600;text-align: center;overflow: hidden;white-space: nowrap;text-overflow: ellipsis;">Banda de pelo y diademas</p></a>
# <a href="https://www.nihaojewelry.com/es/accesorios-pelo-ni-a" style="margin-right: 25px;height: auto;margin-top: 15px;margin-bottom: 15px;display: inline-block;width: 165px;float: right;">
# <img alt="Accesorios Pelo Niña" src="https://img.nihaojewelry.com/media/2021/1/18/1351138048083103744.jpg" style="width: 165px;height: 165px;display: block;"/>
# <p style="font-size: 15px;font-weight: 600;text-align: center;overflow: hidden;white-space: nowrap;text-overflow: ellipsis;">Accesorios Pelo Niña</p></a>
# <a href="https://www.nihaojewelry.com/es/broche-de-pelo" style="margin-left: 25px;display: inline-block;width: 165px;">
# <img alt="Pelo arrugado" src="https://img.nihaojewelry.com/media/2021/1/18/1351139564386914304.jpg" style="width: 165px;height: 165px;display: block;"/>
# <p style="font-size: 15px;font-weight: 600;text-align: center;overflow: hidden;white-space: nowrap;text-overflow: ellipsis;">Pelo arrugado</p></a>
# <a href="https://www.nihaojewelry.com/es/gomas-del-pelo" style="float: right;margin-right: 25px;display: inline-block;width: 165px;">
# <img alt="Clips para el cabello" src="https://img.nihaojewelry.com/media/2021/1/18/1351139320974675968.jpg" style="width: 165px;height: 165px;display: block;"/>
# <p style="font-size: 15px;font-weight: 600;text-align: center;overflow: hidden;white-space: nowrap;text-overflow: ellipsis;">Clips para el cabello</p></a>
# </div>
# </div>
# </div>
# <div class="menu-row">
# <a class="row-link" href="https://www.nihaojewelry.com/es/fine-jewelry" style="height: 38px;">
# <i class="i-menu-3"></i>
# <span>Bisutería Fina</span>
# </a>
# <div class="sub-child">
# <div class="row" style="width: 730px">
# <div class="row-item-fine-jewelry">
# <a class="title-fine-jewelry" href="https://www.nihaojewelry.com/es/crystal-jewelry">Joyería cristal</a>
# <div class="item-list">
# <a href="https://www.nihaojewelry.com/es/crystal-necklaces">Collar Cristal</a>
# <a href="https://www.nihaojewelry.com/es/crystal-earrings">Arete Cristal</a>
# <a href="https://www.nihaojewelry.com/es/crystal-brooches">Broche Cristal</a>
# <a href="https://www.nihaojewelry.com/es/crystal-bracelets">Brazalete Cristal</a>
# <a href="https://www.nihaojewelry.com/es/crystal-rings">Anillo Cristal</a>
# <a href="https://www.nihaojewelry.com/es/crystal-jewelry-sets">Juego de Joyería Cristal</a>
# <a href="https://www.nihaojewelry.com/es/crystal-hair-accessories">Accesorio de Pelo Cristal</a>
# </div>
# </div>
# <div class="row-item-fine-jewelry">
# <a class="title-fine-jewelry" href="https://www.nihaojewelry.com/es/925-silver-jewelry">Joyería Plata 925</a>
# </div>
# <div class="row-item-fine-jewelry">
# <a class="title-fine-jewelry" href="https://www.nihaojewelry.com/es/natural-stone-jewelry">Piedra Natural</a>
# </div>
# <div class="row-item-fine-jewelry">
# <a class="title-fine-jewelry" href="https://www.nihaojewelry.com/es/joyeria-personalizada">Joyería Personalizada</a>
# </div>
# <div class="row-item-fine-jewelry" style="height:130px">
# <a class="title-fine-jewelry" href="https://www.nihaojewelry.com/es/joyas-de-circonio-de-cobre">Joyas de cobre y circonitas</a>
# </div>
# <div class="row-item-fine-jewelry">
# <a class="title-fine-jewelry" href="https://www.nihaojewelry.com/es/titanium-stainless-jewelry">Joyería de acero de Inoxidable</a>
# <div class="item-list">
# <a href="https://www.nihaojewelry.com/es/titanium-stainless-necklaces">Collar Acero ＆Titanio</a>
# <a href="https://www.nihaojewelry.com/es/titanium-stainless-bracelets">Brazalete Acero ＆Titanio</a>
# <a href="https://www.nihaojewelry.com/es/titanium-stainless-earrings">Arete Acero ＆Titanio</a>
# <a href="https://www.nihaojewelry.com/es/titanium-stainless-rings">Anillo Acero ＆Titanio</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="menu-row">
# <a class="row-link" href="https://www.nihaojewelry.com/es/fashion-bags" style="height: 38px;">
# <i class="i-menu-4"></i>
# <span>Bolsos de Moda</span>
# </a>
# <div class="sub-child" style="width: 400px;height: 470px;">
# <div class="row" style="width: 400px;height: 470px;float: left;background-color: #fff;">
# <div class="row-item-fashion-bags">
# <a class="title-1" href="https://www.nihaojewelry.com/es/shoulder-bags">Bolsos para Dama</a>
# </div>
# <div class="row-item-fashion-bags">
# <a class="title-1" href="https://www.nihaojewelry.com/es/backpack">Mochilas</a>
# </div>
# <div class="row-item-fashion-bags">
# <a class="title-1" href="https://www.nihaojewelry.com/es/handbags">Bolsas de Mano</a>
# </div>
# <div class="row-item-fashion-bags">
# <a class="title-1" href="https://www.nihaojewelry.com/es/banquet-bags">Bolsos Fiesta</a>
# </div>
# <div class="row-item-fashion-bags">
# <a class="title-1" href="https://www.nihaojewelry.com/es/wallets">Carteras</a>
# </div>
# <div class="row-fashion-bags-img-1">
# <img alt="Bolsos de Moda 1" src="https://img.nihaojewelry.com/media/2020/7/17/1284026892739022848.jpg"/>
# </div>
# <div class="row-fashion-bags-img-2">
# <a class="a-img" href="https://www.nihaojewelry.com/es/fashion-bags">
# <img alt="fashion bags" src="https://img.nihaojewelry.com/media/2020/8/26/1298465867474014208.jpg" style="height: 455px;margin-top: 5px;"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="menu-row">
# <a class="row-link" href="https://www.nihaojewelry.com/es/women-s-clothing" style="height: 38px;">
# <i class="i-menu-5"></i>
# <span>Ropa de moda</span>
# </a>
# <div class="sub-child" style="width: 400px;height: 470px;">
# <div class="row" style="width: 400px;height: 470px;float: left;background-color: #fff;">
# <div style="float: left;">
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/dresses">Vestidos mujer</a>
# </div>
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/clothing-sets">Conjunto de Ropa</a>
# </div>
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/underwear">Lenceria</a>
# </div>
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/jackets-coats">Abrigo &amp; Chaqueta</a>
# </div>
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/t-shirts">Camiseta</a>
# </div>
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/pants">Pantalones</a>
# </div>
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/pijama">Pijama</a>
# </div>
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/socks">Medias</a>
# </div>
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/plus-size">Tallas Grandes</a>
# </div>
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/scarves">Bufandas</a>
# </div>
# </div>
# <div style="float: right;
#     position: relative;
#     right: 70px;">
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/blouses">Blouses</a>
# </div>
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/parches-para-ropa">Parches para Ropa</a>
# </div>
# <div class="row-item-women-clothing">
# <a class="title-1" href="https://www.nihaojewelry.com/es/sweaters">Suéter</a>
# </div>
# </div>
# <div class="row-women-clothing-img" style="top:130px">
# <a class="a-img" href="https://www.nihaojewelry.com/es/women-s-clothing">
# <img alt="Women’s Clothing" src="https://img.nihaojewelry.com/media/2020/8/26/1298463887531839488.jpg"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="menu-row">
# <a class="row-link" href="https://www.nihaojewelry.com/es/zapatos-de-mujer" style="height: 38px;">
# <i class="i-menu-13"></i>
# <span>Zapatos de Mujer</span>
# </a>
# <div class="sub-child" style="width: 400px;height: 470px;">
# <div class="row" style="width: 400px;height: 470px;float: left;background-color: #fff;">
# <a href="https://www.nihaojewelry.com/es/zaptos-de-tac-n" style="margin-left: 15px;height: auto;margin-top: 15px;">
# <img alt="Tacones altos" src="https://img.nihaojewelry.com/media/2020/5/19/1262626205870460928.jpg"/>
# <p style="font-size: 15px;font-weight: 600;text-align: center;">Tacones altos</p></a>
# <a href="https://www.nihaojewelry.com/es/zapatillas-de-casa" style="margin-left: 25px; display: inline-block"><img alt="Zapatillas de casa" src="https://img.nihaojewelry.com/media/2020/9/15/1305688402712203264.jpg"/>
# <p style="font-size: 15px;font-weight: 600;text-align: center;">Zapatillas de casa</p></a>
# <a href="https://www.nihaojewelry.com/es/zapatos-planos" style="float: right;margin-right: 25px;display: inline-block"><img alt="Zapatos planos" src="https://img.nihaojewelry.com/media/2020/9/15/1305688118128676864.jpg"/>
# <p style="font-size: 15px;font-weight: 600;text-align: center;">Zapatos planos</p></a>
# </div>
# </div>
# </div>
# <div class="menu-row">
# <a class="row-link" href="https://www.nihaojewelry.com/es/fashion-watches" style="height: 38px;">
# <i class="i-menu-6"></i>
# <span>Relojes de Moda</span>
# </a>
# <div class="sub-child" style="width: 400px;height: 470px;">
# <div class="row" style="width: 400px;height: 470px;float: left;background-color: #fff;">
# <div class="row-item-watches">
# <div>
# <a class="a-img" href="https://www.nihaojewelry.com/es/women-s-watches">
# <img alt="Women's Watches" src="https://img.nihaojewelry.com/media/2020/8/26/1298470231651520512.jpg"/>
# <div class="row-watches-title">
#                                                 Relojes mujer
#                                             </div>
# </a>
# </div>
# </div>
# <div class="row-item-watches">
# <div>
# <a class="a-img" href="https://www.nihaojewelry.com/es/men-s-watches">
# <img alt="Men's Watches" src="https://img.nihaojewelry.com/media/2020/8/26/1298470315365634048.jpg"/>
# <div class="row-watches-title">
#                                                 Relojes hombre
#                                             </div>
# </a>
# </div>
# </div>
# <div class="row-item-watches-kid">
# <div>
# <a class="a-img" href="https://www.nihaojewelry.com/es/kids-watches">
# <img alt="Kids Watches" src="https://img.nihaojewelry.com/media/2020/8/26/1298470381518196736.jpg"/>
# <div class="row-watches-title">
#                                                 Relojes Infantil
#                                             </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="menu-row">
# <a class="row-link" href="https://www.nihaojewelry.com/es/scarves" style="height: 38px;">
# <i class="i-menu-7"></i>
# <span>Bufandas</span>
# </a>
# </div>
# <div class="menu-row">
# <a class="row-link" href="https://www.nihaojewelry.com/es/swimwear" style="height: 38px;">
# <i class="i-menu-8"></i>
# <span>Trajes de baño</span>
# </a>
# <div class="sub-child" style="width: 400px;height: 470px;">
# <div class="row" style="width: 400px;height: 470px;float: left;background-color: #fff;">
# <div class="row-item-swimwear">
# <a class="a-img" href="https://www.nihaojewelry.com/es/bikinis">
# <img alt="Wholesale Bikinis" src="https://img.nihaojewelry.com/media/2020/8/26/1298472554398355456.jpg"/>
# <div class="row-swimwear-title">
#                                         Bikini
#                                     </div>
# </a>
# </div>
# <div class="row-item-swimwear">
# <a class="a-img" href="https://www.nihaojewelry.com/es/monokinis">
# <img alt="Wholesale Monokinis" src="https://img.nihaojewelry.com/media/2020/8/26/1298472611298283520.jpg"/>
# <div class="row-swimwear-title">
#                                             Bikini enterizo
#                                         </div>
# </a>
# </div>
# <div class="row-item-swimwear">
# <a class="a-img" href="https://www.nihaojewelry.com/es/plus-size-swimwear">
# <img alt="Plus Size Swimwear" src="https://img.nihaojewelry.com/media/2020/8/26/1298472687911440384.jpg"/>
# <div class="row-swimwear-title">
#                                             Tallas grandes
#                                         </div>
# </a>
# </div>
# <div class="row-item-swimwear">
# <a class="a-img" href="https://www.nihaojewelry.com/es/swimming-accessories">
# <img alt="Swimming Accessories" src="https://img.nihaojewelry.com/media/2020/8/26/1298472753405497344.jpg"/>
# <div class="row-swimwear-title">
#                                             Accesorios de Natación
#                                         </div>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="menu-row">
# <a class="row-link" href="https://www.nihaojewelry.com/es/fashion-accessories" style="height: 38px;">
# <i class="i-menu-9"></i>
# <span>Accesorios de Moda</span>
# </a>
# <div class="sub-child" style="width: 400px;height: 470px;">
# <div class="row" style="width: 400px;height: 470px;float: left;background-color: #fff;">
# <div style="width: 50%; float: left">
# <div class="row-item-fashion-accessories">
# <a class="title-1" href="https://www.nihaojewelry.com/es/fashion-hats">Gorros de Moda</a>
# </div>
# <div class="row-item-fashion-accessories">
# <a class="title-1" href="https://www.nihaojewelry.com/es/fashion-glasses">Lentes de Sol</a>
# </div>
# ...
#                 $value.val(quantity);
#                 $this.trigger('quantity', 'less');
#                 $plus.removeClass('disabled');
#                 if (parseInt($value.val()) === minValue) {
#                     $this.addClass('disabled');
#                 }
#             }
#             var sku = $this.parent().parent().siblings().find('.sku').val();
#             var num = parseInt($this.parent().find('.j_value').val());
#             var args = {
#                 'sku': sku,
#                 'number': num
#             };
#             $.ajax({
#                 type: "post",
#                 url: "https://www.nihaojewelry.com/es/checkout/updateCart",
#                 data: {
#                     skuList: JSON.stringify(args)
#                 },
#                 dataType: "json",
#                 success: function (data) {
#                     if (data != null) {
#                         var currencyRate = data.currencyRate;
#                         var currencySymbol = data.currencySymbol;
#                         $value.val(data.qty);
#                         var price = data.amount * currencyRate;
#                         $this.parent().parent().siblings().find('.j_price').text(currencySymbol + price.toFixed(2));
#                         /*$(".j_total_quantity").text(data.items);*/
#                         var subPrice = data.baseGrandTotal * currencyRate;
#                         $(".j_total_price").text(currencySymbol + subPrice.toFixed(2));
#                     }
#
#                 },
#                 error: function () {
#
#                 }
#             });
#         });
#         $(document).on('click', '.j_calc .j_plus', function () {
#             var $this = $(this);
#             var maxValue = parseInt($this.data('max') || 999);
#             var $value = $this.parent().find('.j_value');
#             var $less = $this.parent().find('.j_less');
#             var _value = parseInt($value.val());
#             if (_value < maxValue || maxValue === 999) {
#                 var quantity = _value + 1;
#                 $value.val(quantity);
#                 $this.trigger('quantity', 'plus');
#                 $less.removeClass('disabled');
#                 if (parseInt($value.val()) === maxValue) {
#                     $this.addClass('disabled');
#                 }
#             }
#             var sku = $this.parent().parent().siblings().find('.sku').val();
#             var num = parseInt($this.parent().find('.j_value').val());
#             var args = {
#                 'sku': sku,
#                 'number': num
#             };
#             $.ajax({
#                 type: "post",
#                 url: "https://www.nihaojewelry.com/es/checkout/updateCart",
#                 data: {
#                     skuList: JSON.stringify(args)
#                 },
#                 dataType: "json",
#                 success: function (data) {
#                     if (data != null) {
#                         var currencyRate = data.currencyRate;
#                         var currencySymbol = data.currencySymbol;
#                         $value.val(data.qty);
#                         var price = data.amount * currencyRate;
#                         $this.parent().parent().siblings().find('.j_price').text(currencySymbol + price.toFixed(2));
#                         /*$(".j_total_quantity").text(data.items);*/
#                         var subPrice = data.baseGrandTotal * currencyRate;
#                         $(".j_total_price").text(currencySymbol + subPrice.toFixed(2));
#
#                     }
#
#                 },
#                 error: function () {
#
#                 }
#             });
#         });
#         $(document).on('change', '.j_calc .j_value', function () {
#             var $this = $(this);
#             var minisale = $this.parent().find('.minisale').val();
#
#             var sku = $this.parent().parent().siblings().find('.sku').val()
#             var num = parseInt($this.val());
#             if (num<minisale) {
#                 return;
#             }
#             var args = {
#                 'sku': sku,
#                 'number': num
#             };
#             $.ajax({
#                 type: "post",
#                 url: "https://www.nihaojewelry.com/es/checkout/updateCart",
#                 data: {
#                     skuList: JSON.stringify(args)
#                 },
#                 dataType: "json",
#                 success: function (data) {
#                     if (data != null) {
#                         var currencyRate = data.currencyRate;
#                         var currencySymbol = data.currencySymbol;
#                         $this.val(data.qty);
#                         var price = data.amount * currencyRate;
#                         $this.parent().parent().siblings().find('.j_price').text(currencySymbol + price.toFixed(2));
#                         /*$(".j_total_quantity").text(data.items);*/
#                         var subPrice = data.baseGrandTotal * currencyRate;
#                         $(".j_total_price").text(currencySymbol + subPrice.toFixed(2));
#                     }
#
#                 },
#                 error: function () {
#
#                 }
#             });
#         });
#     }());
#     // $(function () {
#     //     $('.to-top').toTop(
#     //         {
#     //             //options with default values
#     //             autohide: true,
#     //             offset: 420,
#     //             speed: 100,
#     //             position: true,
#     //             right: 15,
#     //             bottom: 150
#     //         }
#     //     );
#     // });
#
#     function searchPrd() {
#         var val = $(".search-input").val();
#         if (val == null || val == undefined || val == "" || val.length == 0) {
#             return false;
#         } else {
#             return true;
#         }
#
#     }
#
#     $(document).on('click', '.j_select_list li', function (e) {
#         var $this = $(this);
#         var html = $this.find(".title").html();
#         var categoryId = $this.find(".category-id").val();
#         $('.category-name').text(html);
#         $("#categoryId").val(categoryId);
#     });
# </script>
# <!-- Facebook Pixel Code -->
# <script>
#     !function (f, b, e, v, n, t, s) {
#         if (f.fbq) return;
#         n = f.fbq = function () {
#             n.callMethod ?
#                 n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#         };
#         if (!f._fbq) f._fbq = n;
#         n.push = n;
#         n.loaded = !0;
#         n.version = '2.0';
#         n.queue = [];
#         t = b.createElement(e);
#         t.async = !0;
#         t.src = v;
#         s = b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t, s)
#     }(window, document, 'script',
#         'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '593352901086614');
#     fbq('track', 'PageView');
# </script>
# <noscript><img alt="" height="1" src="https://www.facebook.com/tr?id=593352901086614&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <script src="https://www.nihaojewelry.com/js/scooljs.js"></script>
# <script type="text/javascript">
#      picrun_iniMM2()
#  </script>
# <!-- Start of LiveChat (www.livechatinc.com) code -->
# <script type="text/javascript">
#     window.__lc = window.__lc || {};
#     window.__lc.license = 9008470;
#     (function () {
#         var lc = document.createElement('script');
#         lc.type = 'text/javascript';
#         lc.async = true;
#         lc.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'cdn.livechatinc.com/tracking.js';
#         var s = document.getElementsByTagName('script')[0];
#         s.parentNode.insertBefore(lc, s);
#     })();
# </script>
# <!-- End of LiveChat code -->
# <!-- TrustBox script -->
# <script async="" src="//widget.trustpilot.com/bootstrap/v5/tp.widget.bootstrap.min.js" type="text/javascript"></script>
# <!-- End Trustbox script -->
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KZ9LVD7" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <script>
#         $(function () {
#             //分销连接判断
#             if (getQueryVariable("usercode")){
#                 var newusercode=getQueryVariable("usercode");
#                 var usercode=localStorage.getItem("usercode");
#                 if (newusercode !='' && newusercode != undefined && usercode!=newusercode){
#                     localStorage.setItem("usercode",newusercode);
#
#                     //保存当前时间戳
#                     var setTimestamp = new Date().getTime()/1000;
#                     localStorage.setItem("setTimestamp",setTimestamp);
#
#                     var customerSource=document.referrer;
#                     if (customerSource !=''  && customerSource != undefined && customerSource!=null){
#                         if (customerSource.indexOf("nihaojewelry.com")==-1){
#                             localStorage.setItem('customerSource',customerSource);
#                         }
#                     }
#                 }
#             }
#
#             //注册广告分组参数获取
#             if (getQueryVariable("utm_campaign")) {
#                 var utmCampaign = getQueryVariable("utm_campaign");
#                 if (utmCampaign != '' && utmCampaign != undefined) {
#                     localStorage.setItem("utmCampaign", utmCampaign);
#                 }
#             }
#
#             //判断参数
#             if (localStorage.getItem("userReferer")==null){
#                 if (getQueryVariable("utm_source") == "FB") {
#                     localStorage.setItem('userReferer', "FB");
#                 } else if (getQueryVariable("utm_source") == "ADS") {
#                     localStorage.setItem('userReferer', "ADS");
#                 } else if (getQueryVariable("utm_source") == "taboola") {
#                     localStorage.setItem('userReferer', "taboola");
#                 } else {
#                     var referrer = document.referrer;
#                     if (referrer != '' && referrer != undefined && referrer != null) {
#                         if (referrer.indexOf("nihaojewelry.com") == -1 && referrer.indexOf("paypal.com") == -1
#                             && referrer.indexOf("masapay.com") == -1 && referrer.indexOf("oceanpayment.com") == -1) {
#                             //不包含
#                             //判断是否第三方授权登陆
#                             if (referrer.indexOf("dialog/oauth/read/") != -1) {
#                                 //包含
#                                 return;
#                             }
#                             localStorage.setItem('userReferer', referrer);
#                         }
#                     }
#                 }
#
#                 var gclid = getQueryVariable("gclid");
#                 if (gclid != '' && gclid != undefined) {
#                     localStorage.setItem("utmCampaign", gclid);
#                     localStorage.setItem("userReferer", "ADS");
#                 }
#             }
#
#         });
#
#         function getQueryVariable(variable) {
#             var query = window.location.search.substring(1);
#             var vars = query.split("&");
#             for (var i = 0; i < vars.length; i++) {
#                 var pair = vars[i].split("=");
#                 if (pair[0] == variable) {
#                     return pair[1];
#                 }
#             }
#             return (false);
#         }
#     </script>
# <script>
#     let str = '/es';
#     let obj = [];
#
#     //localStorage.setItem('arr', obj);
#
#     function notice() {
#         return 'https://www.nihaojewelry.com/es/browserNotify/list';
#
#     }
#
#     as()
#
#     function as() {
#
#
#         $.getJSON(notice(), function (res) {
#             if (Notification.permission == "granted") {
#
#                 if (localStorage.getItem('arr') == null) {
#                     localStorage.setItem('arr', JSON.stringify(res));
#                     moenth(res);
#
#                 } else {
#
#                     obj = JSON.parse(localStorage.getItem('arr'));
#
#                     let ary = []
#                     for (var i = 0; i < res.length; i++) {
#                         var obq = res[i];
#                         var num = obq.id;
#
#                         var isExist = false;
#                         for (var j = 0; j < obj.length; j++) {
#                             var aj = obj[j];
#                             var n = aj.id;
#
#                             if(n == num){
#                                 isExist = true;
#                                 break;
#
#                             }
#                         }
#                         if(!isExist){
#
#                             ary.push(obq);
#
#                         }
#
#                     }
#                     moenth(ary);
#
#                     localStorage.setItem('arr', JSON.stringify(res));
#
#                 }
#             }
#
#         })
#
#
#     }
#
#
#     function noticed(obj, data) {
#
#         var result = [];
#         for (var i = 0; i < data.length; i++) {
#             var obq = data[i];
#
#             var num = obq.id;
#             var isExist = false;
#             for (var j = 0; j < obj.length; j++) {
#                 var aj = obj[j];
#                 var n = aj.id;
#                 if (n == num) {
#                     isExist = true;
#                     break;
#                 }
#             }
#             if (!isExist) {
#                 result.push(obq);
#
#             }
#         }
#
#         obj = data;
#
#
#     }
#
#     function moenth(data) {
#         for (var z = 0; z < data.length; z++) {
#             let notification = new Notification(data[z].title, {
#                 body: data[z].content,
#                 image: data[z].imageSrc,
#                 data: {
#                     url: data[z].link
#                 }
#             });
#             notification.onclick = function () {
#
#                 window.open(notification.data.url);
#                 notification.close();
#             };
#         }
#     }
#
# </script>
# <script type="text/javascript">
#     var endDateStr ;
#     $(document).ready(function()
#     {
#         $.ajax({
#             url: "https://www.nihaojewelry.com/es/getActiveCountDown",
#             type: "GET",
#             dataType: "json",
#             success: function (data) {
#                 var date = new Date();
#                 var now = getLocalTime(0,date);
#                 //设置截止时间
#                 var startDateStr=data['startDate'];
#                 var startDate = new Date(startDateStr).getTime();
#                 endDateStr=data['endDate'];
#                 var endDate = new Date(endDateStr).getTime();
#                 if (now>startDate&&endDate>now){
#                     countTime();
#                 }
#             }
#         });
#     });
#     function countTime() {
#         //获取当前时间
#
#         var date = new Date();
#         var now = getLocalTime(0,date);
#         //var endDateStr="2020/3/26 06:00:00";
#         var endDate = new Date(endDateStr).getTime();
#         var leftTime = endDate-now;
#         //时间差
#
#         //定义变量 d,h,m,s保存倒计时的时间
#         var d,h,m,s;
#         if (leftTime>=0) {
#             d = Math.floor(leftTime/1000/60/60/24);
#             h = Math.floor(leftTime/(1000*60*60)%24);
#             m = Math.floor(leftTime/1000/60%60);
#             s = Math.floor(leftTime/1000%60);
#             //将倒计时赋值到div中
#             d = checkTime(d);
#             h = checkTime(h);
#             m = checkTime(m);
#             s = checkTime(s);
#             document.getElementById("_d").innerHTML = d;
#             document.getElementById("_h").innerHTML = h;
#             document.getElementById("_m").innerHTML = m;
#             document.getElementById("_s").innerHTML = s;
#             //递归每秒调用countTime方法，显示动态时间效果
#             setTimeout(countTime,1000);
#         }
#
#
#     }
#
#     function checkTime(i) {
#         if (i<10) {
#             i = "0" +i;
#         }
#         return i;
#     };
#
#
#     function getLocalTime(i, d) {
#         //参数i为时区值数字，比如北京为东八区则输入+8,西5输入-5
#         //参数d为要转换的时间(Date类型)
#         if (typeof i !== 'number') return;
#         var len = d.getTime();
#         //本地时间与GMT时间的时间偏移差
#         var offset = d.getTimezoneOffset() * 60000;
#         //得到现在的格林尼治时间
#         var utcTime = len + offset;
#         return utcTime + 3600000 * i;
#     }
# </script>
# </body>
# </html>

# %%
print(page_soup.find("div", class_="g-crumbs g-wrap"))
# Out:
# None

# %%
page_soup.find_all(class_="goods-details-page")
# Out:
# []

# %% [markdown]
# ## mood automatico

# %%
# check each url
for url in urls:
    print(str(url))
    html = requests.get(url)
    soup = BeautifulSoup(html.text, 'html.parser')
    #productDescriptBox = soup.find_all('p', class_="row-head")
    print(soup.find("div", {"class": "goods-details-page"}))

# %%
html = requests.get(urls[0])
soup = BeautifulSoup(html.text, 'html.parser')

# %%
soup.find_all(class_="product-packaging-list")
